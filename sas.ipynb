# %%
import pandas as pd
import numpy as np

# Визуализация
import seaborn as sns
import matplotlib.pyplot as plt

# Обращение к сайтам + bs
from bs4 import BeautifulSoup
import requests

# Регулярные выражения
import re

# %%
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

# %% [markdown]
# # PARSE 1 FORUM

# %% [markdown]
# # PARSE 2 FORUM

# %%
forum2 = "https://forum.sportbox.ru/index.php?showforum=106"

# %%
forum2_df = pd.read_html(requests.get(forum2, headers=header).text)[1]
forum2_df
# Out:
#     Unnamed: 0                                      Название темы  Автор  \
# 0          NaN  Закреплено Плавание  Автор andrew-b, 17 May 20...    NaN
# 1          NaN  Закреплено Синхронное плавание  Автор BiAtloni...    NaN
# 2          NaN  Подскажите Хорошие Часы Для Плавания  Автор Sw...    NaN
# 3          NaN  Опрос Чм-2017 Будапешт, Где Будем Обсуждать И ...    NaN
# 4          NaN  Первенство России 2016 По Синхронному Плаванию...    NaN
# 5          NaN  Чм - 2015 Казань  Автор aleshon, 23 Jul 2015  ...    NaN
# 6          NaN  Собственные рекорды  Автор G_L_A_D_I_A_T_O_R, ...    NaN
# 7          NaN  Спортивное плавание  Автор svetaemelyanova94, ...    NaN
# 8          NaN  Розыгрываются билеты на этап Кубка мира по пла...    NaN
# 9          NaN  ЧМ-2013. Барселона  Автор Hrizantema, 26 Jul 2...    NaN
# 10         NaN  Ошибки и проблемы в плавании  Автор bangtw, 04...    NaN
# 11         NaN         Режим занятий  Автор MARSEL88, 11 Jan 2012    NaN
# 12         NaN  Как попасть на соревнования по плаванию?  Авто...    NaN
# 13         NaN          Олимпиада-2012  Автор bhbfyf, 03 Aug 2012    NaN
# 14         NaN          Анастасия Чаун  Автор IOICOI, 27 Jul 2012    NaN
# 15         NaN               Ян Торп  Автор koly0771, 08 Nov 2011    NaN
# 16         NaN  Заслуженно ли Губерниев комментирует столь важ...    NaN
# 17         NaN  Майкл Фелпс  Автор Evgen_85, 16 Aug 2008  1  2...    NaN
# 18         NaN  Шанхай-2011 что есть. Казань-2015 что будет.  ...    NaN
# 19         NaN          Юлия Ефимова  Автор PermGood, 15 Aug 2008    NaN
# 20         NaN       Анастасия Зуева  Автор PermGood, 15 Aug 2008    NaN
# 21         NaN  Тоня и Соня Волковы  Автор Diman2204, 11 Mar 2011    NaN
# 22         NaN  Почему НИКАК не освещается паралимпийское движ...    NaN
# 23         NaN  Чемпионат Европы  Автор Feklinya, 28 Jul 2010 ...    NaN
# 24         NaN  Объективность судейства.  Автор troyn61, 07 Au...    NaN
# 25         NaN  Новое и интересное в плавании  Автор Koshmatos...    NaN
#
#                                     Статистика             Последнее сообщение
# 0   Горячая тема 139 Ответов  70211 Просмотров            aleshon  24 Feb 2021
# 1                 27 Ответов  35066 Просмотров          alkor1986  21 Jul 2019
# 2                 10 Ответов  16120 Просмотров         SteelBoxer  17 Dec 2019
# 3                   0 Ответов  6527 Просмотров            aleshon  08 Jul 2017
# 4                   0 Ответов  9980 Просмотров          Fotomig33  15 Feb 2016
# 5                 87 Ответов  32278 Просмотров            aleshon  15 Aug 2015
# 6                 45 Ответов  35866 Просмотров         Forever888  22 Apr 2014
# 7                   0 Ответов  8046 Просмотров  svetaemelyanova94  15 Oct 2013
# 8                     1 Ответ  8527 Просмотров           Natashik  02 Oct 2013
# 9                 21 Ответов  17261 Просмотров               eiao  07 Aug 2013
# 10                 4 Ответов  14116 Просмотров           koly0771  20 Jun 2013
# 11                  6 Ответов  8747 Просмотров             Vlad-I  17 Nov 2012
# 12                 4 Ответов  12178 Просмотров            antomas  27 Sep 2012
# 13                  4 Ответов  8143 Просмотров         monic-2007  20 Aug 2012
# 14                  6 Ответов  9891 Просмотров             IOICOI  01 Aug 2012
# 15                  2 Ответов  7956 Просмотров            antomas  24 Nov 2011
# 16  Горячая тема 241 Ответов  69500 Просмотров     Kassandra14_08  01 Nov 2011
# 17                85 Ответов  53653 Просмотров            antomas  26 Aug 2011
# 18                21 Ответов  20106 Просмотров            sharada  21 Aug 2011
# 19                 8 Ответов  13583 Просмотров             Mertox  12 Aug 2011
# 20                17 Ответов  13433 Просмотров             Mertox  12 Aug 2011
# 21                 6 Ответов  12871 Просмотров              BAD1M  29 Jul 2011
# 22                    1 Ответ  9294 Просмотров            sharada  10 Jul 2011
# 23  Горячая тема 899 Ответов  73529 Просмотров              proza  16 Aug 2010
# 24                    1 Ответ  9166 Просмотров              ovgr8  10 Aug 2010
# 25                25 Ответов  28502 Просмотров            vasikol  21 May 2009

# %%
forum2_df.columns
# Out:
# Index(['Unnamed: 0', 'Название темы', 'Автор', 'Статистика',
#        'Последнее сообщение'],
#       dtype='object')

# %%
features_forum2 = ['Название темы', 'Статистика']
stat_forum2 = pd.DataFrame()
stat_forum2['ans'] = forum2_df['Статистика'].apply(lambda it: it.replace('Горячая тема', '')).apply(lambda it: int(it.split()[0]))
stat_forum2['views'] = forum2_df['Статистика'].apply(lambda it: it.replace('Горячая тема', '')).apply(lambda it: int(it.split()[2]))
themes_forum2 = forum2_df['Название темы']

# %%
stat_forum2
# Out:
#     ans  views
# 0   139  70211
# 1    27  35066
# 2    10  16120
# 3     0   6527
# 4     0   9980
# 5    87  32278
# 6    45  35866
# 7     0   8046
# 8     1   8527
# 9    21  17261
# 10    4  14116
# 11    6   8747
# 12    4  12178
# 13    4   8143
# 14    6   9891
# 15    2   7956
# 16  241  69500
# 17   85  53653
# 18   21  20106
# 19    8  13583
# 20   17  13433
# 21    6  12871
# 22    1   9294
# 23  899  73529
# 24    1   9166
# 25   25  28502

# %%
page = requests.get(forum2)
print(page.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
all_links = [a['href'] for a in soup.findAll('a', class_='topic_title')]

# %%
comments = []
for j, link in enumerate(all_links):
    page = requests.get(link)
    soup = BeautifulSoup(page.text, "html.parser")
    p = soup.findAll('li', class_='pagejump')
    if (len(p) == 0):
        p = 1
    else:
        p = int(p[0].find('a').text.split()[3])
    comments.append([])
    for i in range(1, p + 1):
        page = requests.get(link+f'&page={i}')
        soup = BeautifulSoup(page.text, "html.parser")
        com = soup.findAll('div', class_='post')
        for c in com:
            comments[j].append(c.text)
    print(f'end {j}')
# Out:
# end 0
# end 1
# end 2
# end 3
# end 4
# end 5
# end 6
# end 7
# end 8
# end 9
# end 10
# end 11
# end 12
# end 13
# end 14
# end 15
# end 16
# end 17
# end 18
# end 19
# end 20
# end 21
# end 22
# end 23
# end 24
# end 25

# %%
len(comments)
# Out:
# 26
